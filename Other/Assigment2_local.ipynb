# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
        
names_ids = df.index.str.split('\s\(')        
df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df.head()
# Out:
#                #Summer  Gold  Silver  Bronze  Total  #Winter  Gold.1  \
#  Afghanistan        14     0       0       2      2        0       0
#  Algeria            13     5       4       8     17        3       0
#  Argentina          24    21      25      28     74       18       0
#  Armenia             6     2       5       7     14        6       0
#  Australasia         2     3       4       5     12        0       0
#
#               Silver.1  Bronze.1  Total.1  #Total  Gold.2  Silver.2  Bronze.2  \
#  Afghanistan         0         0        0      14       0         0         2
#  Algeria             0         0        0      16       5         4         8
#  Argentina           0         0        0      42      21        25        28
#  Armenia             0         0        0      12       2         5         7
#  Australasia         0         0        0       2       3         4         5
#
#               Total.2   ID
#  Afghanistan        2  AFG
# ...

# %%
max_gold=df[df['Gold']==df['Gold'].max()]
max_gold
# Out:
#                  #Summer  Gold  Silver  Bronze  Total  #Winter  Gold.1  \
#  United States        27  1022     794     704   2520       22      96
#
#                 Silver.1  Bronze.1  Total.1  #Total  Gold.2  Silver.2  \
#  United States       102        84      282      49    1118       896
#
#                 Bronze.2  Total.2   ID
#  United States       788     2802  USA

# %%
max_gold=df.where(df['Gold']==df['Gold'].max())
max_gold
# Out:
#                           #Summer    Gold  Silver  Bronze   Total  #Winter  \
#  Afghanistan                  NaN     NaN     NaN     NaN     NaN      NaN
#  Algeria                      NaN     NaN     NaN     NaN     NaN      NaN
#  Argentina                    NaN     NaN     NaN     NaN     NaN      NaN
#  Armenia                      NaN     NaN     NaN     NaN     NaN      NaN
#  Australasia                  NaN     NaN     NaN     NaN     NaN      NaN
#  Australia                    NaN     NaN     NaN     NaN     NaN      NaN
#  Austria                      NaN     NaN     NaN     NaN     NaN      NaN
#  Azerbaijan                   NaN     NaN     NaN     NaN     NaN      NaN
#  Bahamas                      NaN     NaN     NaN     NaN     NaN      NaN
#  Bahrain                      NaN     NaN     NaN     NaN     NaN      NaN
#  Barbados                     NaN     NaN     NaN     NaN     NaN      NaN
# ...

# %%
answer_two()
# Out:
#  United States    USA
# Name: ID, dtype: object

# %%
(abs(df['Gold']-df['Gold.1'])/df['Gold.2']).max()==(abs(df['Gold']-df['Gold.1'])/df['Gold.2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-a2689dfe2f00> in <module>()
# ----> 1 (abs(df['Gold']-df['Gold.1'])/df['Gold.2']).max()==(abs(df['Gold']-df['Gold.1'])/df['Gold.2'])
#
# D:\Python\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     739             return NotImplemented
#     740         elif isinstance(other, (np.ndarray, pd.Index)):
# --> 741             if len(self) != len(other):
#     742                 raise ValueError('Lengths must match to compare')
#     743             return self._constructor(na_op(self.values, np.asarray(other)),
#
# TypeError: len() of unsized object

# %%
df[df['Gold']-df['Gold.1']==abs(df['Gold']-df['Gold.1']).max()]
# Out:
#                  #Summer  Gold  Silver  Bronze  Total  #Winter  Gold.1  \
#  United States        27  1022     794     704   2520       22      96
#
#                 Silver.1  Bronze.1  Total.1  #Total  Gold.2  Silver.2  \
#  United States       102        84      282      49    1118       896
#
#                 Bronze.2  Total.2   ID
#  United States       788     2802  USA

# %%
max_diff_gold=df.where(abs(df['Gold']-df['Gold.1'])==abs(df['Gold']-df['Gold.1']).max())
max_diff_gold= max_diff_gold.dropna()
max_diff_gold['ID']
# Out:
#  United States    USA
# Name: ID, dtype: object

# %%
def answer_three():
    more_than_one_gold = df[(df['Gold.1']>0) & (df['Gold']>0)]

    max_ratio =(abs(more_than_one_gold['Gold']-more_than_one_gold['Gold.1'])/
                          more_than_one_gold['Gold.2']).max()
    ans3 = more_than_one_gold[(abs(more_than_one_gold['Gold']-more_than_one_gold['Gold.1'])/
                          more_than_one_gold['Gold.2'])==max_ratio]
    return ans3['ID']

# %%
answer_three()
# Out:
#  Bulgaria    BUL
# Name: ID, dtype: object

# %%
points = df['Gold.2']*3+df['Silver.2']*2+df['Bronze.2']*1
points = points[points>0]
points
# Out:
# pandas.core.series.Series

# %%
df[(df['Bronze.2']==0)  & (df['Gold.2']==0) & (df['Silver.2']==0)]
# Out:
# Empty DataFrame
# Columns: [ #Summer, Gold, Silver, Bronze, Total, #Winter, Gold.1, Silver.1, Bronze.1, Total.1, #Total, Gold.2, Silver.2, Bronze.2, Total.2, ID]
# Index: []

# %%
df.where(df['Gold']>0).count()
# Out:
#  #Summer    109
# Gold        109
# Silver      109
# Bronze      109
# Total       109
# #Winter     109
# Gold.1      109
# Silver.1    109
# Bronze.1    109
# Total.1     109
# #Total      109
# Gold.2      109
# Silver.2    109
# Bronze.2    109
# Total.2     109
# ID          109
# dtype: int64
